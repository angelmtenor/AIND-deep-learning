# %% [markdown]
# # Convolutional Neural Networks
#
# Original: https://github.com/udacity/aind2-cnn/tree/master/cifar10-classification
#
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054.0
# Trainable params: 528,054.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=20,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
# Epoch 00000: val_loss improved from inf to 1.30610, saving model to model.weights.best.hdf5
# 9s - loss: 1.5859 - acc: 0.4229 - val_loss: 1.3061 - val_acc: 0.5290
# Epoch 2/20
# Epoch 00001: val_loss improved from 1.30610 to 1.10921, saving model to model.weights.best.hdf5
# 8s - loss: 1.2468 - acc: 0.5556 - val_loss: 1.1092 - val_acc: 0.5990
# Epoch 3/20
# Epoch 00002: val_loss improved from 1.10921 to 1.05805, saving model to model.weights.best.hdf5
# 8s - loss: 1.1276 - acc: 0.6009 - val_loss: 1.0581 - val_acc: 0.6204
# Epoch 4/20
# Epoch 00003: val_loss improved from 1.05805 to 1.00137, saving model to model.weights.best.hdf5
# 8s - loss: 1.0608 - acc: 0.6295 - val_loss: 1.0014 - val_acc: 0.6438
# Epoch 5/20
# Epoch 00004: val_loss did not improve
# 8s - loss: 1.0271 - acc: 0.6420 - val_loss: 1.2052 - val_acc: 0.5948
# Epoch 6/20
# Epoch 00005: val_loss did not improve
# 8s - loss: 1.0029 - acc: 0.6543 - val_loss: 1.0300 - val_acc: 0.6516
# Epoch 7/20
# Epoch 00006: val_loss improved from 1.00137 to 0.96937, saving model to model.weights.best.hdf5
# 9s - loss: 0.9848 - acc: 0.6644 - val_loss: 0.9694 - val_acc: 0.6812
# Epoch 8/20
# Epoch 00007: val_loss did not improve
# 9s - loss: 0.9764 - acc: 0.6660 - val_loss: 1.1335 - val_acc: 0.6490
# Epoch 9/20
# Epoch 00008: val_loss improved from 0.96937 to 0.96006, saving model to model.weights.best.hdf5
# 8s - loss: 0.9788 - acc: 0.6694 - val_loss: 0.9601 - val_acc: 0.6954
# Epoch 10/20
# Epoch 00009: val_loss improved from 0.96006 to 0.94709, saving model to model.weights.best.hdf5
# 8s - loss: 0.9806 - acc: 0.6660 - val_loss: 0.9471 - val_acc: 0.6892
# Epoch 11/20
# Epoch 00010: val_loss did not improve
# 8s - loss: 0.9836 - acc: 0.6726 - val_loss: 0.9709 - val_acc: 0.6782
# Epoch 12/20
# Epoch 00011: val_loss did not improve
# 8s - loss: 0.9968 - acc: 0.6673 - val_loss: 0.9953 - val_acc: 0.6630
# Epoch 13/20
# Epoch 00012: val_loss did not improve
# 8s - loss: 1.0106 - acc: 0.6619 - val_loss: 1.0193 - val_acc: 0.6576
# Epoch 14/20
# Epoch 00013: val_loss did not improve
# 9s - loss: 1.0329 - acc: 0.6573 - val_loss: 1.1926 - val_acc: 0.6788
# Epoch 15/20
# Epoch 00014: val_loss did not improve
# 9s - loss: 1.0521 - acc: 0.6532 - val_loss: 1.2248 - val_acc: 0.6352
# Epoch 16/20
# Epoch 00015: val_loss did not improve
# 8s - loss: 1.0751 - acc: 0.6463 - val_loss: 0.9780 - val_acc: 0.6768
# Epoch 17/20
# Epoch 00016: val_loss did not improve
# 9s - loss: 1.0848 - acc: 0.6418 - val_loss: 0.9547 - val_acc: 0.6912
# Epoch 18/20
# Epoch 00017: val_loss did not improve
# 8s - loss: 1.0972 - acc: 0.6411 - val_loss: 1.3478 - val_acc: 0.5444
# Epoch 19/20
# Epoch 00018: val_loss did not improve
# 8s - loss: 1.1216 - acc: 0.6328 - val_loss: 1.0677 - val_acc: 0.6610
# Epoch 20/20
# Epoch 00019: val_loss did not improve
# 8s - loss: 1.1455 - acc: 0.6272 - val_loss: 1.0397 - val_acc: 0.6770

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6769

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
