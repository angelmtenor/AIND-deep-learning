# %% [markdown]
# # Convolutional Neural Networks
#
# Original: https://github.com/udacity/aind2-cnn/tree/master/cifar10-classification
#
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=3, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 553,514.0
# Trainable params: 553,514.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=128, epochs=30,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 1.44774, saving model to model.weights.best.hdf5
# 5s - loss: 1.7668 - acc: 0.3502 - val_loss: 1.4477 - val_acc: 0.4740
# Epoch 2/30
# Epoch 00001: val_loss improved from 1.44774 to 1.22465, saving model to model.weights.best.hdf5
# 5s - loss: 1.3994 - acc: 0.4934 - val_loss: 1.2246 - val_acc: 0.5718
# Epoch 3/30
# Epoch 00002: val_loss improved from 1.22465 to 1.11623, saving model to model.weights.best.hdf5
# 5s - loss: 1.2564 - acc: 0.5505 - val_loss: 1.1162 - val_acc: 0.6164
# Epoch 4/30
# Epoch 00003: val_loss improved from 1.11623 to 1.04804, saving model to model.weights.best.hdf5
# 5s - loss: 1.1660 - acc: 0.5839 - val_loss: 1.0480 - val_acc: 0.6256
# Epoch 5/30
# Epoch 00004: val_loss improved from 1.04804 to 1.00369, saving model to model.weights.best.hdf5
# 5s - loss: 1.1002 - acc: 0.6099 - val_loss: 1.0037 - val_acc: 0.6484
# Epoch 6/30
# Epoch 00005: val_loss improved from 1.00369 to 0.90322, saving model to model.weights.best.hdf5
# 5s - loss: 1.0461 - acc: 0.6292 - val_loss: 0.9032 - val_acc: 0.6854
# Epoch 7/30
# Epoch 00006: val_loss did not improve
# 5s - loss: 1.0079 - acc: 0.6436 - val_loss: 0.9794 - val_acc: 0.6564
# Epoch 8/30
# Epoch 00007: val_loss improved from 0.90322 to 0.87330, saving model to model.weights.best.hdf5
# 5s - loss: 0.9692 - acc: 0.6569 - val_loss: 0.8733 - val_acc: 0.7000
# Epoch 9/30
# Epoch 00008: val_loss improved from 0.87330 to 0.83883, saving model to model.weights.best.hdf5
# 5s - loss: 0.9362 - acc: 0.6696 - val_loss: 0.8388 - val_acc: 0.7076
# Epoch 10/30
# Epoch 00009: val_loss improved from 0.83883 to 0.78784, saving model to model.weights.best.hdf5
# 5s - loss: 0.9148 - acc: 0.6779 - val_loss: 0.7878 - val_acc: 0.7250
# Epoch 11/30
# Epoch 00010: val_loss did not improve
# 5s - loss: 0.8797 - acc: 0.6902 - val_loss: 0.8285 - val_acc: 0.7120
# Epoch 12/30
# Epoch 00011: val_loss improved from 0.78784 to 0.75782, saving model to model.weights.best.hdf5
# 5s - loss: 0.8548 - acc: 0.6986 - val_loss: 0.7578 - val_acc: 0.7378
# Epoch 13/30
# Epoch 00012: val_loss did not improve
# 5s - loss: 0.8353 - acc: 0.7047 - val_loss: 0.7686 - val_acc: 0.7364
# Epoch 14/30
# Epoch 00013: val_loss improved from 0.75782 to 0.74122, saving model to model.weights.best.hdf5
# 5s - loss: 0.8170 - acc: 0.7115 - val_loss: 0.7412 - val_acc: 0.7440
# Epoch 15/30
# Epoch 00014: val_loss did not improve
# 5s - loss: 0.7938 - acc: 0.7180 - val_loss: 0.7437 - val_acc: 0.7384
# Epoch 16/30
# Epoch 00015: val_loss improved from 0.74122 to 0.71363, saving model to model.weights.best.hdf5
# 5s - loss: 0.7851 - acc: 0.7236 - val_loss: 0.7136 - val_acc: 0.7478
# Epoch 17/30
# Epoch 00016: val_loss did not improve
# 5s - loss: 0.7742 - acc: 0.7268 - val_loss: 0.7152 - val_acc: 0.7518
# Epoch 18/30
# Epoch 00017: val_loss improved from 0.71363 to 0.71344, saving model to model.weights.best.hdf5
# 5s - loss: 0.7484 - acc: 0.7394 - val_loss: 0.7134 - val_acc: 0.7526
# Epoch 19/30
# Epoch 00018: val_loss improved from 0.71344 to 0.68384, saving model to model.weights.best.hdf5
# 5s - loss: 0.7459 - acc: 0.7392 - val_loss: 0.6838 - val_acc: 0.7646
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 5s - loss: 0.7278 - acc: 0.7428 - val_loss: 0.6853 - val_acc: 0.7652
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 5s - loss: 0.7145 - acc: 0.7452 - val_loss: 0.7413 - val_acc: 0.7406
# Epoch 22/30
# Epoch 00021: val_loss did not improve
# 5s - loss: 0.7047 - acc: 0.7483 - val_loss: 0.7329 - val_acc: 0.7444
# Epoch 23/30
# Epoch 00022: val_loss improved from 0.68384 to 0.67696, saving model to model.weights.best.hdf5
# 5s - loss: 0.6952 - acc: 0.7531 - val_loss: 0.6770 - val_acc: 0.7708
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 5s - loss: 0.6847 - acc: 0.7575 - val_loss: 0.6976 - val_acc: 0.7580
# Epoch 25/30
# Epoch 00024: val_loss improved from 0.67696 to 0.66608, saving model to model.weights.best.hdf5
# 5s - loss: 0.6760 - acc: 0.7621 - val_loss: 0.6661 - val_acc: 0.7738
# Epoch 26/30
# Epoch 00025: val_loss improved from 0.66608 to 0.64743, saving model to model.weights.best.hdf5
# 5s - loss: 0.6652 - acc: 0.7642 - val_loss: 0.6474 - val_acc: 0.7728
# Epoch 27/30
# Epoch 00026: val_loss did not improve
# 4s - loss: 0.6601 - acc: 0.7678 - val_loss: 0.6560 - val_acc: 0.7744
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 4s - loss: 0.6594 - acc: 0.7664 - val_loss: 0.6579 - val_acc: 0.7734
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 4s - loss: 0.6399 - acc: 0.7732 - val_loss: 0.6809 - val_acc: 0.7638
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 4s - loss: 0.6414 - acc: 0.7739 - val_loss: 0.6630 - val_acc: 0.7688

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7693

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
