# %% [markdown]
# # Convolutional Neural Networks
#
# Original: https://github.com/udacity/aind2-cnn/tree/master/cifar10-classification
#
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 553,274.0
# Trainable params: 553,274.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=128, epochs=30,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 1.49342, saving model to model.weights.best.hdf5
# 6s - loss: 1.7970 - acc: 0.3457 - val_loss: 1.4934 - val_acc: 0.4736
# Epoch 2/30
# Epoch 00001: val_loss improved from 1.49342 to 1.24649, saving model to model.weights.best.hdf5
# 5s - loss: 1.4255 - acc: 0.4824 - val_loss: 1.2465 - val_acc: 0.5570
# Epoch 3/30
# Epoch 00002: val_loss improved from 1.24649 to 1.11701, saving model to model.weights.best.hdf5
# 5s - loss: 1.2787 - acc: 0.5413 - val_loss: 1.1170 - val_acc: 0.6042
# Epoch 4/30
# Epoch 00003: val_loss improved from 1.11701 to 1.05860, saving model to model.weights.best.hdf5
# 5s - loss: 1.1932 - acc: 0.5719 - val_loss: 1.0586 - val_acc: 0.6326
# Epoch 5/30
# Epoch 00004: val_loss improved from 1.05860 to 1.00030, saving model to model.weights.best.hdf5
# 5s - loss: 1.1245 - acc: 0.5971 - val_loss: 1.0003 - val_acc: 0.6506
# Epoch 6/30
# Epoch 00005: val_loss improved from 1.00030 to 0.95910, saving model to model.weights.best.hdf5
# 5s - loss: 1.0713 - acc: 0.6196 - val_loss: 0.9591 - val_acc: 0.6652
# Epoch 7/30
# Epoch 00006: val_loss improved from 0.95910 to 0.93190, saving model to model.weights.best.hdf5
# 5s - loss: 1.0313 - acc: 0.6315 - val_loss: 0.9319 - val_acc: 0.6752
# Epoch 8/30
# Epoch 00007: val_loss improved from 0.93190 to 0.87386, saving model to model.weights.best.hdf5
# 5s - loss: 0.9953 - acc: 0.6463 - val_loss: 0.8739 - val_acc: 0.6882
# Epoch 9/30
# Epoch 00008: val_loss did not improve
# 5s - loss: 0.9659 - acc: 0.6572 - val_loss: 0.8898 - val_acc: 0.6818
# Epoch 10/30
# Epoch 00009: val_loss did not improve
# 5s - loss: 0.9344 - acc: 0.6684 - val_loss: 0.8793 - val_acc: 0.6902
# Epoch 11/30
# Epoch 00010: val_loss improved from 0.87386 to 0.83966, saving model to model.weights.best.hdf5
# 5s - loss: 0.9111 - acc: 0.6776 - val_loss: 0.8397 - val_acc: 0.7012
# Epoch 12/30
# Epoch 00011: val_loss improved from 0.83966 to 0.83526, saving model to model.weights.best.hdf5
# 5s - loss: 0.8882 - acc: 0.6839 - val_loss: 0.8353 - val_acc: 0.7072
# Epoch 13/30
# Epoch 00012: val_loss improved from 0.83526 to 0.81321, saving model to model.weights.best.hdf5
# 5s - loss: 0.8729 - acc: 0.6906 - val_loss: 0.8132 - val_acc: 0.7142
# Epoch 14/30
# Epoch 00013: val_loss did not improve
# 5s - loss: 0.8550 - acc: 0.6978 - val_loss: 0.8219 - val_acc: 0.7054
# Epoch 15/30
# Epoch 00014: val_loss improved from 0.81321 to 0.75926, saving model to model.weights.best.hdf5
# 5s - loss: 0.8345 - acc: 0.7046 - val_loss: 0.7593 - val_acc: 0.7398
# Epoch 16/30
# Epoch 00015: val_loss did not improve
# 5s - loss: 0.8211 - acc: 0.7078 - val_loss: 0.7836 - val_acc: 0.7268
# Epoch 17/30
# Epoch 00016: val_loss did not improve
# 5s - loss: 0.8046 - acc: 0.7152 - val_loss: 0.7666 - val_acc: 0.7324
# Epoch 18/30
# Epoch 00017: val_loss improved from 0.75926 to 0.74059, saving model to model.weights.best.hdf5
# 5s - loss: 0.7892 - acc: 0.7191 - val_loss: 0.7406 - val_acc: 0.7370
# Epoch 19/30
# Epoch 00018: val_loss did not improve
# 5s - loss: 0.7799 - acc: 0.7253 - val_loss: 0.7655 - val_acc: 0.7316
# Epoch 20/30
# Epoch 00019: val_loss did not improve
# 5s - loss: 0.7669 - acc: 0.7271 - val_loss: 0.7528 - val_acc: 0.7340
# Epoch 21/30
# Epoch 00020: val_loss improved from 0.74059 to 0.71841, saving model to model.weights.best.hdf5
# 5s - loss: 0.7486 - acc: 0.7347 - val_loss: 0.7184 - val_acc: 0.7518
# Epoch 22/30
# Epoch 00021: val_loss improved from 0.71841 to 0.71688, saving model to model.weights.best.hdf5
# 5s - loss: 0.7408 - acc: 0.7372 - val_loss: 0.7169 - val_acc: 0.7450
# Epoch 23/30
# Epoch 00022: val_loss did not improve
# 5s - loss: 0.7228 - acc: 0.7412 - val_loss: 0.7222 - val_acc: 0.7504
# Epoch 24/30
# Epoch 00023: val_loss did not improve
# 5s - loss: 0.7154 - acc: 0.7440 - val_loss: 0.7454 - val_acc: 0.7442
# Epoch 25/30
# Epoch 00024: val_loss did not improve
# 5s - loss: 0.7120 - acc: 0.7476 - val_loss: 0.7170 - val_acc: 0.7504
# Epoch 26/30
# Epoch 00025: val_loss improved from 0.71688 to 0.70975, saving model to model.weights.best.hdf5
# 5s - loss: 0.7017 - acc: 0.7500 - val_loss: 0.7097 - val_acc: 0.7596
# Epoch 27/30
# Epoch 00026: val_loss improved from 0.70975 to 0.70307, saving model to model.weights.best.hdf5
# 5s - loss: 0.6947 - acc: 0.7503 - val_loss: 0.7031 - val_acc: 0.7534
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 5s - loss: 0.6893 - acc: 0.7545 - val_loss: 0.7072 - val_acc: 0.7564
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 5s - loss: 0.6745 - acc: 0.7608 - val_loss: 0.7165 - val_acc: 0.7556
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 5s - loss: 0.6662 - acc: 0.7618 - val_loss: 0.7054 - val_acc: 0.7600

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7476

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
